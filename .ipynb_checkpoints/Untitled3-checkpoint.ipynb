# %%
import pandas as pd
df = pd.read_csv("dragging system.csv")
df.head()
# Out:
#    Sr. No.       HMR          Remarks Unnamed: 3
# 0        1   99051.0  drag_chain_slip        NaN
# 1        2   99526.0  drag_chain_slip        NaN
# 2        3  100123.5        drag_rope        NaN
# 3        4  100141.0        drag_rope        NaN
# 4        5  100183.0        drag_rope        NaN

# %%
df.drop(['Sr. No.','Unnamed: 3'],axis='columns', inplace=True) 
df.head()
# Out:
#         HMR          Remarks
# 0   99051.0  drag_chain_slip
# 1   99526.0  drag_chain_slip
# 2  100123.5        drag_rope
# 3  100141.0        drag_rope
# 4  100183.0        drag_rope

# %%
dummies= pd.get_dummies(df.Remarks)
dummies
# Out:
#      drag chain  drag chain link broken  drag chain problem  \
# 0             0                       0                   0
# 1             0                       0                   0
# 2             0                       0                   0
# 3             0                       0                   0
# 4             0                       0                   0
# ..          ...                     ...                 ...
# 265           0                       0                   0
# 266           0                       0                   0
# 267           0                       0                   0
# 268           0                       0                   0
# 269           0                       0                   0
#
#      drag drum drive break  drag rope out from pulley  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# ...

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#           HMR          Remarks  drag chain  drag chain link broken  \
# 0     99051.0  drag_chain_slip           0                       0
# 1     99526.0  drag_chain_slip           0                       0
# 2    100123.5        drag_rope           0                       0
# 3    100141.0        drag_rope           0                       0
# 4    100183.0        drag_rope           0                       0
# ..        ...              ...         ...                     ...
# 265  173720.5    drag_rope_out           0                       0
# 266  173880.5    drag_rope_out           0                       0
# 267  173990.0    drag_rope_out           0                       0
# 268  174073.5    drag_rope_out           0                       0
# 269  174407.0    drag_rope_out           0                       0
#
#      drag chain problem  drag drum drive break  drag rope out from pulley  \
# 0                     0                      0                          0
# ...

# %%
final = merged.drop(['Remarks','drag chain','drag chain link broken','drag chain problem','drag drum drive break'],axis='columns')
final
# Out:
#           HMR  drag rope out from pulley  drag socket pin lock broken  \
# 0     99051.0                          0                            0
# 1     99526.0                          0                            0
# 2    100123.5                          0                            0
# 3    100141.0                          0                            0
# 4    100183.0                          0                            0
# ..        ...                        ...                          ...
# 265  173720.5                          0                            0
# 266  173880.5                          0                            0
# 267  173990.0                          0                            0
# 268  174073.5                          0                            0
# 269  174407.0                          0                            0
#
#      drag walk problem  drag_chain  drag_chain_slip  drag_rope  drag_rope_out
# ...

# %%
inputs = final.drop('drag_rope',axis='columns')
target= final.drag_rope
