# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dragline data.csv')

# %%
df
# Out:
#     Unnamed: 0  Rigging                               Unnamed: 2  \
# 0      Sr. No.       HMR                                 Remarks
# 1            1   98678.5                        Dump rope broken
# 2            2     98731  Dump rope broken(New dump rope fitted)
# 3            3   99039.5                        Dump rope broken
# 4            4     99703              Dump rope ,Dump socket pin
# ..         ...       ...                                     ...
# 267        266    173482                         dump rope broke
# 268        267  173880.5                         dump rope broke
# 269        268    174194                         dump rope broke
# 270        269       NaN                                     NaN
# 271        270       NaN                                     NaN
#
#     Dragging system               Unnamed: 4     HOIST  \
# 0               HMR                  Remarks       HMR
# 1             99051  Drag rope cut from drum  103678.5
# ...

# %%
df1= pd.read_excel('dragline data.xlsx')

# %%
df1
# Out:
#     Unnamed: 0 Rigging                               Unnamed: 2  \
# 0      Sr. No.      HMR                                 Remarks
# 1            1  98678.5                        Dump rope broken
# 2            2    98731  Dump rope broken(New dump rope fitted)
# 3            3  99039.5                        Dump rope broken
# 4            4    99703              Dump rope ,Dump socket pin
# ..         ...      ...                                     ...
# 267        266   173482                         dump rope broke
# 268        267   173880                         dump rope broke
# 269        268   174194                         dump rope broke
# 270        269      NaN                                     NaN
# 271        270      NaN                                     NaN
#
#     Dragging system               Unnamed: 4   HOIST  \
# 0               HMR                  Remarks     HMR
# 1             99051  Drag rope cut from drum  103678
# ...

# %%
df.head()
# Out:
#   Unnamed: 0 Rigging                               Unnamed: 2 Dragging system  \
# 0    Sr. No.      HMR                                 Remarks             HMR
# 1          1  98678.5                        Dump rope broken           99051
# 2          2    98731  Dump rope broken(New dump rope fitted)           99526
# 3          3  99039.5                        Dump rope broken          100124
# 4          4    99703              Dump rope ,Dump socket pin          100141
#
#                 Unnamed: 4   HOIST                  Unnamed: 6
# 0                  Remarks     HMR                     Remarks
# 1  Drag rope cut from drum  103678     hoist brake not working
# 2   Drag chain line broken  105158       hoist shakle pin  out
# 3         Drag rope broken  110937  hoist rope,hoist brake jam
# 4         drag rope broken  111304     hoist chain link broken

# %%
df2 = pd.read_csv('dragging system.csv')

# %%
df2
# Out:
#      Sr. No.       HMR                  Remarks
# 0          1   99051.0  Drag rope cut from drum
# 1          2   99526.0   Drag chain line broken
# 2          3  100123.5         Drag rope broken
# 3          4  100141.0         drag rope broken
# 4          5  100183.0   drag chain line broken
# ..       ...       ...                      ...
# 265      266  173720.5             drag system
# 266      267  173880.5                drag rope
# 267      268  173990.0               drag chain
# 268      269  174073.5                drag walk
# 269      270  174407.0   drag chain link broken
#
# [270 rows x 3 columns]

# %%
df3 = pd
